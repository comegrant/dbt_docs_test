# %% [markdown]
# ### Note: prior to running the notebook, ensure your kernel is correctly selected and preferably pointing to the venv associated with menu planning project

# %% [markdown]
# # 1. Load libraries

# %%
import random
import numpy as np
import pandas as pd
import sys

sys.path.append("../menu_optimiser")

#load correct ENV 
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
from data_contracts.helper import camel_to_snake
from data_contracts.sources import azure_dl_creds

# %% [markdown]
# # 2. Import data

# %%
df_recipes = await azure_dl_creds.directory("data-science").directory("test-folder").directory("MP20").parquet_at("PIM_RecipeBank_GL_PRD").to_pandas()

# %%
type(df_recipes)
# Out:
# pandas.core.frame.DataFrame

# %%
df_recipes.shape
# Out:
# (17946, 13)

# %%
df_recipes.shape
# Out:
# (17946, 13)

# %%
df_recipes.dtypes
# Out:
# RecipeId                     int32
# MainRecipeId               float64
# MainIngredientId           float64
# NumberOfRatings            float64
# AverageRating               object
# TaxonomyId                   int32
# Price                       object
# IsUniverse                    bool
# CookingTimeFrom              int32
# CookingTimeTo                int32
# PriceCategory                int32
# CreatedAt           datetime64[ns]
# UpdatedAt           datetime64[ns]
# dtype: object

# %%
df_recipes.head(5)
# Out:
#    RecipeId  MainRecipeId  MainIngredientId  NumberOfRatings  \
# 0       748           NaN               2.0              NaN
# 1      3232           NaN               1.0            383.0
# 2      5381           NaN               1.0              5.0
# 3      6757           NaN               1.0              5.0
# 4      7226           NaN               5.0              1.0
#
#            AverageRating  TaxonomyId                  Price  IsUniverse  \
# 0                  0E-18        2079                  0E-18       False
# 1  79.750000000000000000         151  35.170000000000000000       False
# 2  95.000000000000000000         217  30.910000000000000000       False
# 3  80.000000000000000000         244  29.080000000000000000       False
# 4  50.000000000000000000         244  28.860000000000000000       False
#
#    CookingTimeFrom  CookingTimeTo  PriceCategory               CreatedAt  \
# 0               25             30              0 2018-02-20 15:00:36.690
# 1               20             25              1 2018-02-20 15:00:36.690
# 2               20             30              0 2018-05-16 15:12:22.977
# 3               30             30              0 2018-08-06 14:00:38.593
# 4               20             30              0 2018-08-31 13:17:47.613
#
#                 UpdatedAt
# 0                     NaT
# 1 2018-11-29 11:41:53.577
# 2 2019-05-13 16:18:27.530
# 3 2019-06-21 13:56:35.947
# 4 2021-09-02 14:17:35.610

# %%
#Convert all columns to snake case
df_recipes.columns = pd.Index([camel_to_snake(x) for x in df_recipes.columns.to_list()])
df_recipes.sample(3)
# Out:
#        recipe_id  main_recipe_id  main_ingredient_id  number_of_ratings  \
# 5209       63850             NaN                 5.0              827.0
# 16730      83000             NaN                 1.0               16.0
# 400        33324             NaN                 3.0                NaN
#
#               average_rating  taxonomy_id                  price  is_universe  \
# 5209   79.750000000000000000         3653  29.390000000000000000         True
# 16730  65.750000000000000000         2010                  0E-18        False
# 400                    0E-18         1898  31.070000000000000000        False
#
#        cooking_time_from  cooking_time_to  price_category  \
# 5209                  20               30               0
# 16730                 15               20               1
# 400                   20               30               0
#
#                    created_at              updated_at
# 5209  2022-02-28 14:56:50.897 2025-03-12 12:48:54.007
# 16730 2024-02-20 08:19:37.667 2024-04-11 09:47:14.340
# 400   2021-01-26 16:32:37.470 2021-02-03 11:12:08.130

# %%
# Assuming df is your DataFrame with columns 'a' and 'b' where a=RecipeId and b=TaxonomyId


# Calculate the count of unique values in column 'b' for each unique value in column 'a'
#In other words, we are coutning the unique taxonomies per unique recipe, followed by filtering for recipes that have >= 7 taxonomies

count_values = df_recipes.groupby('recipe_id')['taxonomy_id'].nunique()

# Specify the threshold
threshold = 7  # Adjust this threshold as needed to simulate filtering, can be 7,8,9,10 etc

# Filter 'a' values based on the threshold
valid_a_values = count_values[count_values >= threshold].index.tolist()

# Filter the original DataFrame based on the valid 'a' values
filtered_df = df_recipes[df_recipes['recipe_id'].isin(valid_a_values)]

filtered_df
# Out:
#        recipe_id  main_recipe_id  main_ingredient_id  number_of_ratings  \
# 261        26371             NaN                 1.0             1619.0
# 262        26371             NaN                 1.0             1619.0
# 263        26371             NaN                 1.0             1619.0
# 264        26371             NaN                 1.0             1619.0
# 265        26371             NaN                 1.0             1619.0
# ...          ...             ...                 ...                ...
# 17926      77248             NaN                 7.0               34.0
# 17927      77248             NaN                 7.0               34.0
# 17928      77248             NaN                 7.0               34.0
# 17929      77248             NaN                 7.0               34.0
# 17930      77248             NaN                 7.0               34.0
#
#               average_rating  taxonomy_id                  price  is_universe  \
# 261    82.750000000000000000          922  34.250000000000000000         True
# 262    82.750000000000000000         1212  34.250000000000000000         True
# 263    82.750000000000000000         1213  34.250000000000000000         True
# 264    82.750000000000000000         1837  34.250000000000000000         True
# 265    82.750000000000000000         2011  34.250000000000000000         True
# ...                      ...          ...                    ...          ...
# 17926  74.250000000000000000         1177                  0E-18        False
# 17927  74.250000000000000000         1837                  0E-18        False
# 17928  74.250000000000000000         1838                  0E-18        False
# 17929  74.250000000000000000         2013                  0E-18        False
# 17930  74.250000000000000000         2016                  0E-18        False
#
#        cooking_time_from  cooking_time_to  price_category  \
# 261                   20               30               1
# 262                   20               30               1
# 263                   20               30               1
# 264                   20               30               1
# 265                   20               30               1
# ...                  ...              ...             ...
# 17926                 20               30               0
# 17927                 20               30               0
# 17928                 20               30               0
# 17929                 20               30               0
# 17930                 20               30               0
#
#                    created_at              updated_at
# 261   2018-06-26 07:30:52.247 2025-03-11 18:00:06.693
# 262   2018-06-26 07:30:52.247 2025-03-11 18:00:06.693
# 263   2018-06-26 07:30:52.247 2025-03-11 18:00:06.693
# 264   2018-06-26 07:30:52.247 2025-03-11 18:00:06.693
# 265   2018-06-26 07:30:52.247 2025-03-11 18:00:06.693
# ...                       ...                     ...
# 17926 2021-01-21 08:11:38.343 2021-05-31 07:33:58.080
# 17927 2021-01-21 08:11:38.343 2021-05-31 07:33:58.080
# 17928 2021-01-21 08:11:38.343 2021-05-31 07:33:58.080
# 17929 2021-01-21 08:11:38.343 2021-05-31 07:33:58.080
# 17930 2021-01-21 08:11:38.343 2021-05-31 07:33:58.080
#
# [5513 rows x 13 columns]

# %%
filtered_df.shape
# Out:
# (5513, 13)

# %%
count_values = filtered_df.groupby('recipe_id')['taxonomy_id'].nunique()
count_values.mean()
# Out:
# 7.978292329956584

# %%
#Create function to generate random input for the menu optimiser in JSON format
def get_randon_input(df):
    num_recipes = 50
    recipes_list = [str(recipe) for recipe in df['recipe_id'].unique()]
    taxonomies = list(np.random.choice(filtered_df['taxonomy_id'].unique(), 2))
    quantities_max = int(num_recipes / 2)
    required_recipes = random.sample(recipes_list, int(num_recipes * 0.1))
    quantity_1 = np.random.randint(int(quantities_max/2),quantities_max + 1)
    quantity_2 = np.random.randint(int(quantities_max/2),quantities_max + 1)
    




    return {"week":47,
            "year":2024,

            "companies":
            [
            {"company_id":"09ecd4f0-ae58-4539-8e8f-9275b1859a19",
            "num_recipes":num_recipes,
            "required_recipes":required_recipes,
            "available_recipes":recipes_list,

            "taxonomies":
                [{"taxonomy_id":taxonomies[0],
                "quantity":quantity_1,
                "taxonomy_type_id":0,
                "min_average_rating":70,

                "main_ingredients":
                                [{"main_ingredient_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[0]]['main_ingredient_id'].unique()),
                                "quantity":np.random.randint(int(quantity_1/2), quantity_1 + 1)}],
                "cooking_times":[
                                {"time_from":20,
                                "time_to":30,
                                "quantity":20}],
                "price_categories":
                                [{"price_category_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[0]]['price_category'].unique()),
                                "quantity":np.random.randint(int(quantity_1/2), quantity_1 + 1)}]},


                {"taxonomy_id":taxonomies[1],
                "quantity":quantity_2,
                "taxonomy_type_id":0,
                "min_average_rating":70,

                "main_ingredients":
                                [{"main_ingredient_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[1]]['main_ingredient_id'].unique()),
                                "quantity":np.random.randint(int(quantity_2/2), quantity_2 + 1)}],
                "cooking_times":[
                                {"time_from":20,
                                "time_to":30,
                                "quantity":20}],
                "price_categories":
                                [{"price_category_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[1]]['price_category'].unique()),
                                "quantity":np.random.randint(int(quantity_2/2), quantity_2 + 1)}]} ]}]}

# %%
input_json = get_randon_input(filtered_df)

# %%
from optimization import generate_menu_companies_sous_chef

# %%
generate_menu_companies_sous_chef(week=input_json["week"], year=input_json["year"], companies=input_json['companies'], input_df=df_recipes)
# Out:
# /Users/niladri.banerjee/Documents/sous-chef/projects/menu-optimiser/notebooks/../menu_optimiser/optimization.py:398: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PIM_data_excluded[COOKING_TIME_COLUMN] = PIM_data_excluded.apply(
# /Users/niladri.banerjee/Documents/sous-chef/projects/menu-optimiser/notebooks/../menu_optimiser/optimization.py:398: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PIM_data_excluded[COOKING_TIME_COLUMN] = PIM_data_excluded.apply(
# {'year': 2024,
#  'week': 47,
#  'companies': [{'company_id': '09ecd4f0-ae58-4539-8e8f-9275b1859a19',
#    'taxonomies': [{'taxonomy_id': 2015,
#      'wanted': 15,
#      'actual': 15,
#      'main_ingredients': [{'main_ingredient_id': 1, 'wanted': 7, 'actual': 8}],
#      'price_categories': [{'price_category_id': 1,
#        'wanted': 10,
#        'actual': 10}],
#      'cooking_times': [{'from': 20, 'to': 30, 'wanted': 20, 'actual': 15}]},
#     {'taxonomy_id': 953,
#      'wanted': 15,
#      'actual': 15,
#      'main_ingredients': [{'main_ingredient_id': 8,
#        'wanted': 14,
#        'actual': 1}],
#      'price_categories': [{'price_category_id': 1, 'wanted': 13, 'actual': 5}],
#      'cooking_times': [{'from': 20, 'to': 30, 'wanted': 20, 'actual': 15}]}],
#    'recipes': [{'recipe_id': 78005,
#      'main_ingredient_id': 7,
#      'is_constraint': True},
#     {'recipe_id': 64412, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 96372, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 61403, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 53423, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 64762, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 63146, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 44727, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 50435, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 51121, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 79354, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 51252, 'main_ingredient_id': 13, 'is_constraint': True},
#     {'recipe_id': 51279, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 53493, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 95828, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 65139, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 51683, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 64393, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 48912, 'main_ingredient_id': 8, 'is_constraint': True},
#     {'recipe_id': 53604, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 61667, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 63078, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 63338, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 64447, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 47949, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 64409, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 64037, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 48100, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 64267, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 64794, 'main_ingredient_id': 8, 'is_constraint': True},
#     {'recipe_id': 64465, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 48170, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 63277, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 47646, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 64423, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 76998, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 73093, 'main_ingredient_id': 1, 'is_constraint': False},
#     {'recipe_id': 79469, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 83411, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 48180, 'main_ingredient_id': 3, 'is_constraint': False},
#     {'recipe_id': 61264, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 64273, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 63786, 'main_ingredient_id': 3, 'is_constraint': False},
#     {'recipe_id': 55781, 'main_ingredient_id': 3, 'is_constraint': False},
#     {'recipe_id': 45067, 'main_ingredient_id': 1, 'is_constraint': False},
#     {'recipe_id': 78009, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 64311, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 63341, 'main_ingredient_id': 3, 'is_constraint': False},
#     {'recipe_id': 66036, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 47732, 'main_ingredient_id': 1, 'is_constraint': False}]}],
#  'STATUS': 1,
#  'STATUS_MSG': "COMPANY 09ecd4f0-ae58-4539-8e8f-9275b1859a19: TAXONOMY 2015 WARNING! RECIPES WITH COOKING TIMES BETWEEN ['cooking_time_20_30'] not fulfilled. Number of Recipes needed to fulfill constraints is 15, adding 0 random recipes. TAXONOMY 953 WARNING! INGREDIENTS 8 not fulfilled.RECIPES WITH PRICES CATEGORIES [1] not fulfilled.RECIPES WITH COOKING TIMES BETWEEN ['cooking_time_20_30'] not fulfilled. Number of Recipes needed to fulfill constraints is 15, adding 0 random recipes."}
