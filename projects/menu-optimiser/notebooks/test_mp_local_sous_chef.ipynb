# %% [markdown]
# ### Note: prior to running the notebook, ensure your kernel is correctly selected and preferrably pointing to the venv associated with menu planning project

# %%
import random
import numpy as np
import pandas as pd
import sys

sys.path.append("../menu_optimiser")

#load correct ENV 
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
#Attempting import of data from datalake using data_contracts internal package
from data_contracts.sources import data_science_data_lake


df_recipes = await(data_science_data_lake.
                directory("test-folder/MP20/").
                parquet_at("PIM_RecipeBank_GL_QA").
                to_pandas())

# %%
type(df_recipes)
# Out:
# pandas.core.frame.DataFrame

# %%
df_recipes.shape
# Out:
# (72510, 13)

# %%
df_recipes.dtypes
# Out:
# RecipeId                     int32
# MainRecipeId               float64
# MainIngredientId           float64
# NumberOfRatings            float64
# AverageRating               object
# TaxonomyId                   int32
# Price                       object
# IsUniverse                    bool
# CookingTimeFrom              int32
# CookingTimeTo                int32
# PriceCategory                int32
# CreatedAt           datetime64[ns]
# UpdatedAt           datetime64[ns]
# dtype: object

# %%
df_recipes.head(5)
# Out:
#    RecipeId  MainRecipeId  MainIngredientId  NumberOfRatings  \
# 0        87           NaN               2.0              NaN
# 1       114           NaN               2.0              NaN
# 2       196           NaN               2.0              NaN
# 3       788           NaN               2.0            103.0
# 4       864           NaN               5.0              NaN
#
#            AverageRating  TaxonomyId  Price  IsUniverse  CookingTimeFrom  \
# 0                  0E-18           4  0E-18       False               20
# 1                  0E-18           4  0E-18       False               30
# 2                  0E-18           4  0E-18       False               20
# 3  75.750000000000000000           4  0E-18       False               25
# 4                  0E-18           4  0E-18       False               35
#
#    CookingTimeTo  PriceCategory               CreatedAt UpdatedAt
# 0             25              0 2018-02-20 15:00:36.690       NaT
# 1             35              3 2018-02-20 15:00:36.690       NaT
# 2             25              1 2018-02-20 15:00:36.690       NaT
# 3             30              0 2018-02-20 15:00:36.690       NaT
# 4             40              0 2018-02-20 15:00:36.690       NaT

# %%
#Making a function for this as is needed in the code of menu optimiser

def camel_to_snake(s):
    return ''.join(['_'+c.lower() if c.isupper() else c for c in s]).lstrip('_')

# %%
df_recipes.columns = pd.Index([camel_to_snake(x) for x in df_recipes.columns.to_list()])
df_recipes.sample(3)
# Out:
#        recipe_id  main_recipe_id  main_ingredient_id  number_of_ratings  \
# 67747      64426             NaN                 5.0              395.0
# 46388      22404             NaN                 1.0                3.0
# 59371      14682             NaN                 7.0               10.0
#
#               average_rating  taxonomy_id                  price  is_universe  \
# 67747  81.000000000000000000         1837                  0E-18         True
# 46388  83.250000000000000000          986  32.830000000000000000        False
# 59371  75.000000000000000000         1025  30.130000000000000000        False
#
#        cooking_time_from  cooking_time_to  price_category  \
# 67747                 20               30               0
# 46388                 20               30               2
# 59371                 20               30               1
#
#                    created_at              updated_at
# 67747 2018-06-04 16:08:10.377 2024-06-26 06:29:15.560
# 46388 2020-02-03 15:01:22.897 2020-05-06 08:40:03.137
# 59371 2019-05-23 12:48:32.000 2021-05-05 18:57:13.447

# %%
# Assuming df is your DataFrame with columns 'a' and 'b' where a=RecipeId and b=TaxonomyId


# Calculate the count of unique values in column 'b' for each unique value in column 'a'
#In other words, we are coutning the unique taxonomies per unique recipe, followed by filtering for recipes that have >= 7 taxonomies

count_values = df_recipes.groupby('recipe_id')['taxonomy_id'].nunique()

# Specify the threshold
threshold = 7  # Adjust this threshold as needed

# Filter 'a' values based on the threshold
valid_a_values = count_values[count_values >= threshold].index.tolist()

# Filter the original DataFrame based on the valid 'a' values
filtered_df = df_recipes[df_recipes['recipe_id'].isin(valid_a_values)]

filtered_df
# Out:
#        recipe_id  main_recipe_id  main_ingredient_id  number_of_ratings  \
# 8            892             NaN                 2.0               73.0
# 19          5113             NaN                 5.0               18.0
# 21          6746             NaN                 2.0                NaN
# 145         6598             NaN                 5.0               20.0
# 155         7216             NaN                 5.0               15.0
# ...          ...             ...                 ...                ...
# 72500      86168             NaN                 5.0               25.0
# 72502      87083             NaN                 3.0                NaN
# 72503      87149             NaN                 5.0                NaN
# 72504      87153             NaN                 1.0                NaN
# 72505      89497             NaN                 1.0                NaN
#
#               average_rating  taxonomy_id                  price  is_universe  \
# 8      77.000000000000000000            4                  0E-18        False
# 19     83.250000000000000000            4  27.440000000000000000        False
# 21                     0E-18            4  25.900000000000000000        False
# 145    72.500000000000000000            5  26.280000000000000000        False
# 155    78.250000000000000000            5  28.110000000000000000        False
# ...                      ...          ...                    ...          ...
# 72500  90.000000000000000000         2145                  0E-18         True
# 72502                  0E-18         2145                  0E-18         True
# 72503                  0E-18         2145                  0E-18         True
# 72504                  0E-18         2145                  0E-18         True
# 72505                  0E-18         2145                  0E-18         True
#
#        cooking_time_from  cooking_time_to  price_category  \
# 8                     35               35              -3
# 19                    20               30               0
# 21                    25               30               0
# 145                   15               15               0
# 155                   15               15               0
# ...                  ...              ...             ...
# 72500                 20               30               0
# 72502                 20               30              -2
# 72503                 25               35              -1
# 72504                 20               30              -1
# 72505                 20               30              -1
#
#                    created_at              updated_at
# 8     2018-02-20 15:00:36.690                     NaT
# 19                        NaT 2018-05-22 09:12:33.760
# 21    2018-08-06 13:22:16.743 2018-08-20 12:43:05.113
# 145   2018-07-31 09:32:00.867 2018-11-11 19:19:55.497
# 155   2018-08-31 11:43:34.493 2018-10-31 17:37:30.243
# ...                       ...                     ...
# 72500 2024-04-17 15:08:07.917 2024-06-26 06:29:15.560
# 72502 2024-05-02 13:48:26.933 2024-07-01 08:22:03.973
# 72503 2024-05-03 12:45:49.330 2024-07-01 08:28:46.667
# 72504 2024-05-06 09:33:37.937 2024-07-01 08:25:56.547
# 72505 2024-06-21 13:13:08.567 2024-09-02 10:50:21.113
#
# [46628 rows x 13 columns]

# %%
count_values = filtered_df.groupby('recipe_id')['taxonomy_id'].nunique()
count_values.mean()
# Out:
# 8.998070243149364

# %%
#Create function to get random input for the menu optimiser
def get_randon_input(df):
    num_recipes = 50
    recipes_list = [str(recipe) for recipe in df['recipe_id'].unique()]
    taxonomies = list(np.random.choice(filtered_df['taxonomy_id'].unique(), 2))
    quantities_max = int(num_recipes / 2)
    required_recipes = random.sample(recipes_list, int(num_recipes * 0.1))
    quantity_1 = np.random.randint(int(quantities_max/2),quantities_max + 1)
    quantity_2 = np.random.randint(int(quantities_max/2),quantities_max + 1)
    




    return {"week":47,
            "year":2024,

            "companies":
            [
            {"company_id":"09ecd4f0-ae58-4539-8e8f-9275b1859a19",
            "num_recipes":num_recipes,
            "required_recipes":required_recipes,
            "available_recipes":recipes_list,

            "taxonomies":
                [{"taxonomy_id":taxonomies[0],
                "quantity":quantity_1,
                "taxonomy_type_id":0,
                "min_average_rating":70,

                "main_ingredients":
                                [{"main_ingredient_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[0]]['main_ingredient_id'].unique()),
                                "quantity":np.random.randint(int(quantity_1/2), quantity_1 + 1)}],
                "cooking_times":[
                                {"time_from":20,
                                "time_to":30,
                                "quantity":20}],
                "price_categories":
                                [{"price_category_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[0]]['price_category'].unique()),
                                "quantity":np.random.randint(int(quantity_1/2), quantity_1 + 1)}]},


                {"taxonomy_id":taxonomies[1],
                "quantity":quantity_2,
                "taxonomy_type_id":0,
                "min_average_rating":70,

                "main_ingredients":
                                [{"main_ingredient_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[1]]['main_ingredient_id'].unique()),
                                "quantity":np.random.randint(int(quantity_2/2), quantity_2 + 1)}],
                "cooking_times":[
                                {"time_from":20,
                                "time_to":30,
                                "quantity":20}],
                "price_categories":
                                [{"price_category_id": np.random.choice(filtered_df[filtered_df['taxonomy_id'] == taxonomies[1]]['price_category'].unique()),
                                "quantity":np.random.randint(int(quantity_2/2), quantity_2 + 1)}]} ]}]}

# %%
input_json = get_randon_input(filtered_df)

# %%
from optimization import generate_menu_companies_sous_chef

# %%
generate_menu_companies_sous_chef(week=input_json["week"], year=input_json["year"], companies=input_json['companies'], input_df=df_recipes)
# Out:
# /Users/niladri.banerjee/Documents/sous-chef/projects/menu-optimiser/notebooks/../menu_optimiser/optimization.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PIM_data_excluded[COOKING_TIME_COLUMN] = PIM_data_excluded.apply(
# /Users/niladri.banerjee/Documents/sous-chef/projects/menu-optimiser/notebooks/../menu_optimiser/optimization.py:124: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   out = out.applymap(
# /Users/niladri.banerjee/Documents/sous-chef/projects/menu-optimiser/notebooks/../menu_optimiser/optimization.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PIM_data_excluded[COOKING_TIME_COLUMN] = PIM_data_excluded.apply(
# /Users/niladri.banerjee/Documents/sous-chef/projects/menu-optimiser/notebooks/../menu_optimiser/optimization.py:124: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   out = out.applymap(
# {'year': 2024,
#  'week': 47,
#  'companies': [{'company_id': '09ecd4f0-ae58-4539-8e8f-9275b1859a19',
#    'taxonomies': [{'taxonomy_id': 1011,
#      'wanted': 13,
#      'actual': 13,
#      'main_ingredients': [{'main_ingredient_id': 3, 'wanted': 7, 'actual': 7}],
#      'price_categories': [{'price_category_id': 0,
#        'wanted': 11,
#        'actual': 11}],
#      'cooking_times': [{'from': 20, 'to': 30, 'wanted': 20, 'actual': 12}]},
#     {'taxonomy_id': 62,
#      'wanted': 17,
#      'actual': 14,
#      'main_ingredients': [{'main_ingredient_id': 5,
#        'wanted': 14,
#        'actual': 14}],
#      'price_categories': [{'price_category_id': 1, 'wanted': 10, 'actual': 5}],
#      'cooking_times': [{'from': 20, 'to': 30, 'wanted': 20, 'actual': 1}]}],
#    'recipes': [{'recipe_id': 15847,
#      'main_ingredient_id': 2,
#      'is_constraint': True},
#     {'recipe_id': 9698, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 10326, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 22663, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 10480, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 9589, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 9743, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 17051, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 47730, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 48594, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 55350, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 63280, 'main_ingredient_id': 1, 'is_constraint': True},
#     {'recipe_id': 63447, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 63853, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 64552, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 74882, 'main_ingredient_id': 7, 'is_constraint': True},
#     {'recipe_id': 76575, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 78012, 'main_ingredient_id': 3, 'is_constraint': True},
#     {'recipe_id': 4529, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 5096, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 5644, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 5859, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 5878, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 6107, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 6231, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 6282, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 6292, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 6413, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 6501, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 7131, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 7263, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 22295, 'main_ingredient_id': 5, 'is_constraint': True},
#     {'recipe_id': 22573, 'main_ingredient_id': 1, 'is_constraint': False},
#     {'recipe_id': 14116, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 14101, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 48925, 'main_ingredient_id': 8, 'is_constraint': False},
#     {'recipe_id': 68833, 'main_ingredient_id': 1, 'is_constraint': False},
#     {'recipe_id': 64624, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 11661, 'main_ingredient_id': 9, 'is_constraint': False},
#     {'recipe_id': 50252, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 12057, 'main_ingredient_id': 2, 'is_constraint': False},
#     {'recipe_id': 8667, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 21722, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 76402, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 10160, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 11482, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 7732, 'main_ingredient_id': 5, 'is_constraint': False},
#     {'recipe_id': 67354, 'main_ingredient_id': 7, 'is_constraint': False},
#     {'recipe_id': 15486, 'main_ingredient_id': 1, 'is_constraint': False},
#     {'recipe_id': 61416, 'main_ingredient_id': 7, 'is_constraint': False}]}],
#  'STATUS': 1,
#  'STATUS_MSG': "COMPANY 09ecd4f0-ae58-4539-8e8f-9275b1859a19: TAXONOMY 1011 WARNING! RECIPES WITH COOKING TIMES BETWEEN ['cooking_time_20_30'] not fulfilled. TAXONOMY 62 WARNING! NOT ENOUGH RECIPES.RECIPES WITH PRICES CATEGORIES [1] not fulfilled.RECIPES WITH COOKING TIMES BETWEEN ['cooking_time_20_30'] not fulfilled."}
